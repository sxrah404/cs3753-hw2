# %% [markdown]
# <a href="https://colab.research.google.com/github/sxrah404/cs3753-hw2/blob/main/tvf413_hw2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Instructions:
#
# 1. Download the file tvf413_hw2.ipynb
# 2. Open the file via Google Colab
# 3. You can run everything at once by clicking "Run all"

# %%
from matplotlib import pyplot as plt
import numpy as np
import pdb # this is for debugging your code
import pandas as pd

#Question 1

# Read the data from the file fdata.csv using read_csv() and save the data in df.
# The reference of read_csv(): https://www.geeksforgeeks.org/python-read-csv-using-pandas-read_csv/
# You need to set the parameters (sep, parse_dates, index_col) in read_csv() properly
#df = pd.read_csv(XXX, sep=XXX, parse_dates=XXX, index_col=XXX)

#1. your code is here
df = pd.read_csv('https://raw.githubusercontent.com/sxrah404/cs3753-hw2/refs/heads/main/fdata.csv', sep=',', parse_dates=['Date'], index_col='Date')

# plot the figure
df.plot()
plt.show()

#Question 2

# Save the data in the variable "data"
# Each row is saved in a tuple
data = [('2016-10-03', 772.559998), ('2016-10-04', 776.429993), ('2016-10-05', 776.469971), ('2016-10-06', 776.859985), ('2016-10-07', 775.080017)]

#2. your code is here
dates = [item[0] for item in data]
close_values = [item[1] for item in data]

# Plot the data as a red line with round markers

#3. your code is here
plt.figure(figsize=(8, 6))
plt.plot(dates, close_values, color='red', marker='o', linestyle='-', linewidth=2, markersize=8)

# set the ticks, labels, titles, grids
#4. your code is here
plt.xlabel('Date')
plt.ylabel('Closing Value')
plt.title('Closing Stock Value of Alphabet Inc.')

# Turn on the minor TICKS, which are required for the minor GRID
plt.minorticks_on()

# Customize the major grid
#5. your code is here
plt.grid(which='major', linestyle='-', linewidth='0.5', color='red')

# Customize the minor grid
#6. your code is here
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='red')

plt.show()


#Question 3

# please save assign the data in variables
#popularity = [XXX, XXX, ...]
# 1. your code is here
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# plot the bar chart
# plt.XXX(XXX, XXX, color=XXX)
# 2. your code is here
plt.figure(figsize=(8, 6))
plt.bar(languages, popularity, color='blue')

# set ticks, labels, titles, grids
#3. your code is here
plt.xlabel('Languages')
plt.ylabel('Popularity')
plt.title('Popularity of Programming Languages\nWorldwide, Oct 2017 compared to a year ago')

# Turn on the grid
#4. your code is here
plt.grid(True, axis='y', linestyle='-', linewidth='0.5', color='red')
plt.minorticks_on()
plt.grid(which='minor', axis='y', linestyle=':', linewidth='0.5', color='red')

plt.show()

#Question 4
# save the data in variables
#1. your code is here
languages = ['Java', 'Python', 'PHP', 'JavaScript', 'C#', 'C++']
popularity = [22.2, 17.6, 8.8, 8, 7.7, 6.7]

# plot the bar chart
#2. your code is here
plt.figure(figsize=(8, 6))
plt.barh(languages, popularity, color='green')

plt.xlabel('Popularity')
plt.ylabel('Languages')
plt.title('Popularity of Programming Languages\nWorldwide, Oct 2017 compared to a year ago')

plt.grid(True, axis='x', linestyle='-', linewidth='0.5', color='red')
plt.minorticks_on()
plt.grid(which='minor', axis='x', linestyle=':', linewidth='0.5', color='red')

plt.show()

#Question 5
weight1=[67,57.2,59.6,59.64,55.8,61.2,60.45,61,56.23,56]
height1=[101.7,197.6,98.3,125.1,113.7,157.7,136,148.9,125.3,114.9]
weight2=[61.9,64,62.1,64.2,62.3,65.4,62.4,61.4,62.5,63.6]
height2=[152.8,155.3,135.1,125.2,151.3,135,182.2,195.9,165.1,125.1]
weight3=[68.2,67.2,68.4,68.7,71,71.3,70.8,70,71.1,71.7]
height3=[165.8,170.9,192.8,135.4,161.4,136.1,167.1,235.1,181.1,177.3]
# your code is here to draw the scatter plot
plt.figure(figsize=(8, 6))

plt.scatter(weight1, height1, color='red', marker='*', s=100, label='Group 1')
plt.scatter(weight2, height2, color='green', marker='*', s=100, label='Group 2')
plt.scatter(weight3, height3, color='blue', marker='*', s=100, label='Group 3')

plt.xlabel('Weight')
plt.ylabel('Height')
plt.title('Group Wise Weight vs Height')

plt.legend()

plt.show()
# Out:
# /tmp/ipython-input-3028880801.py:14: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv('https://raw.githubusercontent.com/sxrah404/cs3753-hw2/refs/heads/main/fdata.csv', sep=',', parse_dates=['Date'], index_col='Date')
